# %%
import numpy as np
import matplotlib.pyplot as plt

# Define a função
def f(x):
    return 6*x**3 + 31*x**2 + 3*x - 10


x = np.linspace(0, 5, 400)
y = f(x)


plt.figure(figsize=(8, 4))
plt.plot(x, y, label='f(x) = x³ - 6x² + 11x - 6')
plt.axhline(0, color='gray', linewidth=0.5)
plt.title('Resolvendo Equações Graficamente')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <function f at 0x1117314e0>
